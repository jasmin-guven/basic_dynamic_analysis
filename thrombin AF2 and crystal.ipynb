# %%
plt.rcParams.update({'font.size': 15})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 plt.rcParams.update({'font.size': 15})
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
path = "../Desktop/"

# %%
thrombin_data = pd.read_csv(path + "thrombin_data.csv")
thrombin_ligand = thrombin_data["ligand"].to_numpy()
thrombin_af2 = thrombin_data["AF2_ddG"].to_numpy()
thrombin_exp = thrombin_data["exp_ddG"].to_numpy()
thrombin_cry = thrombin_data["crystal_ddG"].to_numpy()

# %%
from sklearn.preprocessing import minmax_scale
err_scaled = minmax_scale(thrombin_data['error_dG'].values)

# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# err_scaled =scaler.fit_transform(thrombin_data['error_dG'].values.reshape(-2,2)).ravel()

# %%
fig = plt.figure(figsize=(8, 8))
sns.set(style="ticks", font_scale=2.5)
ax = fig.add_subplot(111)
ax.set_xlabel(r"$\Delta \Delta G_{\mathrm{Xtal}}$ (kcal mol$^{-1}}$)")
ax.set_ylabel(r"$\Delta \Delta G_{\mathrm{AF2}}$ (kcal mol$^{-1}}$)")
ax.set_xlim(-2,2.5)
ax.set_ylim(-2,2.5)
x=[-2,2.5]
y=[-2,2.5]
ax.plot(x,y, linestyle ="--", c="grey")
ax.set_xticks(np.arange(-2,2.5))
ax.set_yticks(np.arange(-2,2.5))

# ax.set_xlim((-2,3.5))
# ax.set_ylim((-2,3.5))

fill_x = np.linspace(-2,2.5)

ax.fill_between(fill_x,fill_x-2,fill_x+2,color='gainsboro')
ax.fill_between(fill_x,fill_x-1,fill_x+1,color='darkgrey')


ax.errorbar(thrombin_cry[:-2],thrombin_af2[:-2],fmt='o',c='b')


plt.show()
plt.savefig(path+"thrombin_plot.jpg")

# %% [markdown]
# ## thrombin_data = pd.read_csv(path + "thrombin_data.csv")
# thrombin_ligand = thrombin_data["ligand"].to_numpy()
# thrombin_af2 = thrombin_data["AF2_ddG"].to_numpy()
# thrombin_exp = thrombin_data["exp_ddG"].to_numpy()

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
ax.scatter(thrombin_exp, thrombin_af2, marker="o", c="orange")
ax.set_xlabel(r"$\Delta \Delta G_{\mathrm{EXP}}$ (kcal mol$^{-1}}$)", fontsize=14)
ax.set_ylabel(r"$\Delta \Delta G_{\mathrm{AF2}}$ (kcal mol$^{-1}}$)", fontsize=14)
ax.set_xlim(-1,2)
ax.set_ylim(-1,2)

import matplotlib.pyplot as plt
x=[-1,2]
y=[-1,2]
plt.plot(x,y, linestyle ="--", c="black")
plt.show()

# %%
np.linspace(0,4)
# Out:
# array([0.        , 0.08163265, 0.16326531, 0.24489796, 0.32653061,
#        0.40816327, 0.48979592, 0.57142857, 0.65306122, 0.73469388,
#        0.81632653, 0.89795918, 0.97959184, 1.06122449, 1.14285714,
#        1.2244898 , 1.30612245, 1.3877551 , 1.46938776, 1.55102041,
#        1.63265306, 1.71428571, 1.79591837, 1.87755102, 1.95918367,
#        2.04081633, 2.12244898, 2.20408163, 2.28571429, 2.36734694,
#        2.44897959, 2.53061224, 2.6122449 , 2.69387755, 2.7755102 ,
#        2.85714286, 2.93877551, 3.02040816, 3.10204082, 3.18367347,
#        3.26530612, 3.34693878, 3.42857143, 3.51020408, 3.59183673,
#        3.67346939, 3.75510204, 3.83673469, 3.91836735, 4.        ])

# %%
np.arange(0,5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
jnk1_exp[:-2]
# Out:
# array([0.        , 0.56459593, 0.61526903, 0.71944973, 0.98283027,
#        1.02593704, 1.05042406, 1.27019843, 1.32381271, 1.57365039,
#        1.60696529, 1.66863427, 1.88840864, 2.0656713 , 2.0656713 ,
#        2.0957346 , 2.2839033 , 2.29461967, 2.68899503])

# %%
jnk1_af2[-2]
# Out:
# 0.478

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(jnk1_data['error_for_IC50'].values.reshape(-1,1))
# Out:
# array([[-0.46386436],
#        [-0.42417399],
#        [-0.45535928],
#        [-0.46102934],
#        [-0.42984404],
#        [-0.43834912],
#        [-0.3618034 ],
#        [-0.43267907],
#        [-0.33628816],
#        [-0.30226784],
#        [-0.45819431],
#        [-0.20020688],
#        [-0.27108255],
#        [-0.12933122],
#        [-0.34195822],
#        [-0.31077292],
#        [-0.07263068],
#        [ 0.01242012],
#        [ 0.38097358],
#        [ 4.06650826],
#        [ 1.42993345]])
